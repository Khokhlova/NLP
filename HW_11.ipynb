# %% [markdown]
# # Модель Transformer-1

# %% [markdown]
# #### Задание
# 1. Взять предобученную трансформерную архитектуру и решить задачу перевода
# 2. (дополнительная не обязательная задача) взять датасет из datasets для задачи классификации на русском языке затем взять модель которая предобучена на такой задачи классификации и замерить качество до обучения и после обучения на этом датасете

# %%
# Установка
# conda install -c conda-forge transformers

# %%
# Импорт библиотек

import tensorflow as tf
import transformers
from transformers import pipeline

# %% [markdown]
# #### Перевод с английского на немецкий

# %%
# Загрузка датасета

from datasets import load_dataset

dataset = load_dataset("opus_books", lang1="de", lang2="en")
# Out:
# Using custom data configuration de-en-lang1=de,lang2=en
# Reusing dataset opus_books (/Users/evgeniya/.cache/huggingface/datasets/opus_books/de-en-lang1=de,lang2=en/0.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 51467
#     })
# })

# %%
# Разбивка данных на тренировочную и тестовую выборки

split_datasets = dataset["train"].train_test_split(train_size=0.9, seed=17)
split_datasets
# Out:
# Loading cached split indices for dataset at /Users/evgeniya/.cache/huggingface/datasets/opus_books/de-en-lang1=de,lang2=en/0.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf/cache-ddfbfb99a6bf2447.arrow and /Users/evgeniya/.cache/huggingface/datasets/opus_books/de-en-lang1=de,lang2=en/0.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf/cache-c2c940abbaa9f592.arrow
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 46320
#     })
#     test: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 5147
#     })
# })

# %%
# Пример данных

split_datasets["train"][1]["translation"]
# Out:
# {'de': '»Sie werden die ägyptischen Pyramiden hinaufklettern!« murmelte er. »Aber annoncieren Sie nur immer auf Ihre eigene Gefahr hin!',
#  'en': '"You shall walk up the pyramids of Egypt!" he growled. "At your peril you advertise!'}

# %%
# Загрузка пайплайна

from transformers import pipeline

translator = pipeline("translation_en_to_de")
# Out:
# No model was supplied, defaulted to t5-base (https://huggingface.co/t5-base)
# /Users/evgeniya/miniforge3/lib/python3.9/site-packages/transformers/models/t5/tokenization_t5_fast.py:156: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
# Проверка работы пайплайна

translator("How are you?")
# Out:
# [{'translation_text': 'Wie sind Sie?'}]

# %%
# Загрузка предобученного токенайзера

from transformers import AutoTokenizer

model_checkpoint = "Helsinki-NLP/opus-mt-en-de"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, return_tensors="tf")

# %%
# Разбивка данных по языкам и токенизация

en_sentence = split_datasets["train"][1]["translation"]["en"]
de_sentence = split_datasets["train"][1]["translation"]["de"]

inputs = tokenizer(en_sentence)
with tokenizer.as_target_tokenizer():
    targets = tokenizer(de_sentence)

# %%
# Препроцессинг

max_input_length = 128
max_target_length = 128


def preprocess_function(examples):
    inputs = [ex["en"] for ex in examples["translation"]]
    targets = [ex["de"] for ex in examples["translation"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

    # Set up the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_datasets = split_datasets.map(
    preprocess_function,
    batched=True,
    remove_columns=split_datasets["train"].column_names,
)
# Out:
# Parameter 'function'=<function preprocess_function at 0x2cb19b670> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
#   0%|          | 0/47 [00:00<?, ?ba/s]
#   0%|          | 0/6 [00:00<?, ?ba/s]

# %%
# Загрузка предобученной модели

from transformers import TFAutoModelForSeq2SeqLM

model = TFAutoModelForSeq2SeqLM.from_pretrained(model_checkpoint, from_pt=True)
# Out:
# 2022-06-21 15:30:45.479799: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-21 15:30:45.480051: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1
# All PyTorch model weights were used when initializing TFMarianMTModel.
#
# All the weights of TFMarianMTModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFMarianMTModel for predictions without further training.

# %%
# Перевод

text = 'The greatest glory in living lies not in never falling, but in rising every time we fall'

inputs = tokenizer.encode(text, return_tensors="tf")
outputs = model.generate(inputs, max_length=40, num_beams=4, early_stopping=True)

# %%
print(tokenizer.decode(outputs[0]))
# Out:
# <pad> Der größte Ruhm im Leben liegt nicht darin, nie zu fallen, sondern darin, jedes Mal aufzusteigen, wenn wir fallen<pad><pad><pad>

# %% [markdown]
# #### Классификация текстов

# %%
# Импорт библиотек, загрузка токенизатора и модели 

from transformers import TFAutoModelForSequenceClassification
from transformers import BertTokenizerFast

tokenizer = BertTokenizerFast.from_pretrained('blanchefort/rubert-base-cased-sentiment-rurewiews', return_tensors="tf")
model = TFAutoModelForSequenceClassification.from_pretrained('blanchefort/rubert-base-cased-sentiment-rurewiews', return_dict=True)
# Out:
# Downloading:   0%|          | 0.00/495 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/950 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/679M [00:00<?, ?B/s]
# Some layers from the model checkpoint at blanchefort/rubert-base-cased-sentiment-rurewiews were not used when initializing TFBertForSequenceClassification: ['dropout_37']
# - This IS expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertForSequenceClassification were initialized from the model checkpoint at blanchefort/rubert-base-cased-sentiment-rurewiews.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.

# %%
# # Импорт библиотек, загрузка токенизатора и модели 

# from transformers import AutoTokenizer, TFAutoModelForSequenceClassification

# tokenizer = AutoTokenizer.from_pretrained("blanchefort/rubert-base-cased-sentiment-rusentiment", max_length=100, padding = "max_length", return_tensors="tf")

# model = TFAutoModelForSequenceClassification.from_pretrained("blanchefort/rubert-base-cased-sentiment-rusentiment")
# Out:
# Some layers from the model checkpoint at blanchefort/rubert-base-cased-sentiment-rusentiment were not used when initializing TFBertForSequenceClassification: ['dropout_37']
# - This IS expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertForSequenceClassification were initialized from the model checkpoint at blanchefort/rubert-base-cased-sentiment-rusentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.

# %%
# Загрузка пайплайна

from transformers import pipeline

classifier = pipeline("text-classification", tokenizer = tokenizer, model = model)

# %%
# Загрузка датасета

from datasets import load_dataset

dataset = load_dataset("blinoff/healthcare_facilities_reviews")
# Out:
# Reusing dataset healthcare_facilities_reviews (/Users/evgeniya/.cache/huggingface/datasets/blinoff___healthcare_facilities_reviews/simple/1.0.0/d61498aa2f506f5e71bb46794c1b010c56c842dd03b36556cb67744a57dc916e)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['content', 'title', 'sentiment', 'category', 'review_id', 'source_url', 'Idx'],
#         num_rows: 70597
#     })
#     validation: Dataset({
#         features: ['content', 'title', 'sentiment', 'category', 'review_id', 'source_url', 'Idx'],
#         num_rows: 70597
#     })
# })

# %%
# Исключение лишниш столбцов

dataset = dataset.remove_columns(['title', 'category', 'review_id', 'source_url', 'Idx'])

# %%
# Энкодинг таргета

dataset = dataset.rename_column('sentiment', 'label')
dataset = dataset.class_encode_column('label')

# %%
# Разбивка данных на тренировочную и тестовую выборки

split_datasets = dataset["train"].train_test_split(train_size=0.9, seed=17)
split_datasets
# Out:
# Loading cached split indices for dataset at /Users/evgeniya/.cache/huggingface/datasets/blinoff___healthcare_facilities_reviews/simple/1.0.0/d61498aa2f506f5e71bb46794c1b010c56c842dd03b36556cb67744a57dc916e/cache-9b8e37ef50014fb4.arrow and /Users/evgeniya/.cache/huggingface/datasets/blinoff___healthcare_facilities_reviews/simple/1.0.0/d61498aa2f506f5e71bb46794c1b010c56c842dd03b36556cb67744a57dc916e/cache-b15f7c34ef348024.arrow
# DatasetDict({
#     train: Dataset({
#         features: ['content', 'sentiment'],
#         num_rows: 63537
#     })
#     test: Dataset({
#         features: ['content', 'sentiment'],
#         num_rows: 7060
#     })
# })

# %%
# Пример данных

print(split_datasets["train"][0],
      split_datasets["train"][1],
      split_datasets["train"][2])
# Out:
# {'content': 'При госпитализации в больницу могут предложить услуги посредника! Особенно наглый Корпорация семейной медицины! Сумма госпитализации завышена в разы ( говорят, что берут за курацию), договор дают не на госпитализацию, а общий! Потом еще требуют доплаты хотя в платном отделе больницы счет меньше! Ужас!', 'sentiment': 'negative'} {'content': 'Ужасное отношение, диагноз выдуман, снимок не смог нормально прочитать стоматолог. Не советую! Прием 15.08.15.', 'sentiment': 'negative'} {'content': 'В нашей семье случилась беда. Сын стал наркоманом. Мы узнали о клинике доктора Исаева случайно, т. к. не обладали никакой информацией по этому вопросу. Сына после клиники отправили в центр "Не зависимость", где с ним занималась Марьяна-мониторный психолог. Благодаря её профессионализму, самоотдаче, чётко проведённой методике, душевности. чуткости и заботе наш сын стал совершенно другим человеком. Нет слов, чтобы выразить от всего сердца благодарность Марьяне. Побольше бы таких высококлассных специалистов!Михаил, папа Л.', 'sentiment': 'positive'}

# %%
# Проверка работы предобученной модели

print(classifier(split_datasets["train"]['content'][0]),
      classifier(split_datasets["train"]['content'][1]),
      classifier(split_datasets["train"]['content'][2]))
# Out:
# [{'label': 'NEGATIVE', 'score': 0.8474009037017822}] [{'label': 'NEGATIVE', 'score': 0.9199402928352356}] [{'label': 'NEGATIVE', 'score': 0.7423568367958069}]

# %% [markdown]
# В одном случае из трех предобученная модель ошиблась

# %%
data = split_datasets["test"]["content"]
raw_predictions = classifier(data)

# %%
raw_predictions
# Out:
# [{'label': 'NEUTRAL', 'score': 0.529673159122467},
#  {'label': 'NEUTRAL', 'score': 0.554032564163208},
#  {'label': 'POSITIVE', 'score': 0.7349655032157898},
#  {'label': 'NEGATIVE', 'score': 0.6967583298683167},
#  {'label': 'NEUTRAL', 'score': 0.5432539582252502},
#  {'label': 'NEUTRAL', 'score': 0.4575249254703522},
#  {'label': 'NEUTRAL', 'score': 0.5524546504020691},
#  {'label': 'POSITIVE', 'score': 0.9534175395965576},
#  {'label': 'POSITIVE', 'score': 0.8425549268722534},
#  {'label': 'NEGATIVE', 'score': 0.8536224961280823},
#  {'label': 'NEGATIVE', 'score': 0.5404945015907288},
#  {'label': 'NEGATIVE', 'score': 0.7912715077400208},
#  {'label': 'NEGATIVE', 'score': 0.6760830879211426},
#  {'label': 'POSITIVE', 'score': 0.9848350286483765},
#  {'label': 'NEUTRAL', 'score': 0.3977958858013153},
#  {'label': 'NEUTRAL', 'score': 0.6265783309936523},
#  {'label': 'NEGATIVE', 'score': 0.6176688075065613},
#  {'label': 'NEUTRAL', 'score': 0.6236677169799805},
#  {'label': 'POSITIVE', 'score': 0.45551377534866333},
#  {'label': 'NEGATIVE', 'score': 0.6943696141242981},
#  {'label': 'NEGATIVE', 'score': 0.5309625267982483},
#  {'label': 'NEGATIVE', 'score': 0.6107644438743591},
#  {'label': 'POSITIVE', 'score': 0.8289089798927307},
#  {'label': 'POSITIVE', 'score': 0.9070194959640503},
#  {'label': 'NEUTRAL', 'score': 0.6263253092765808},
#  {'label': 'POSITIVE', 'score': 0.9918838739395142},
#  {'label': 'POSITIVE', 'score': 0.7690330147743225},
#  {'label': 'POSITIVE', 'score': 0.4411609172821045},
#  {'label': 'NEUTRAL', 'score': 0.5160261392593384},
#  {'label': 'NEGATIVE', 'score': 0.44789397716522217},
#  {'label': 'NEGATIVE', 'score': 0.566986620426178},
#  {'label': 'POSITIVE', 'score': 0.4583946764469147},
#  {'label': 'NEUTRAL', 'score': 0.5599038600921631},
#  {'label': 'POSITIVE', 'score': 0.4385027289390564},
#  {'label': 'POSITIVE', 'score': 0.9920728802680969},
#  {'label': 'NEGATIVE', 'score': 0.5737621784210205},
#  {'label': 'NEGATIVE', 'score': 0.5213724970817566},
#  {'label': 'POSITIVE', 'score': 0.9660907983779907},
#  {'label': 'NEUTRAL', 'score': 0.7367261052131653},
#  {'label': 'POSITIVE', 'score': 0.993930459022522},
#  {'label': 'POSITIVE', 'score': 0.9920503497123718},
#  {'label': 'POSITIVE', 'score': 0.9945921301841736},
#  {'label': 'POSITIVE', 'score': 0.48540228605270386},
#  {'label': 'NEGATIVE', 'score': 0.7305797934532166},
#  {'label': 'NEUTRAL', 'score': 0.43275538086891174},
#  {'label': 'NEGATIVE', 'score': 0.75803142786026},
#  {'label': 'NEGATIVE', 'score': 0.3554815948009491},
#  {'label': 'NEUTRAL', 'score': 0.49739503860473633},
#  {'label': 'NEGATIVE', 'score': 0.6369034051895142},
#  {'label': 'NEUTRAL', 'score': 0.5408030152320862},
#  {'label': 'POSITIVE', 'score': 0.68709796667099},
#  {'label': 'POSITIVE', 'score': 0.9938674569129944},
#  {'label': 'POSITIVE', 'score': 0.9926422238349915},
#  {'label': 'NEUTRAL', 'score': 0.542150616645813},
#  {'label': 'NEUTRAL', 'score': 0.5269855856895447},
#  {'label': 'NEGATIVE', 'score': 0.7658054232597351},
#  {'label': 'NEGATIVE', 'score': 0.7645111680030823},
#  {'label': 'POSITIVE', 'score': 0.9662296772003174},
#  {'label': 'NEUTRAL', 'score': 0.5077983736991882},
#  {'label': 'NEGATIVE', 'score': 0.7438071966171265},
#  {'label': 'POSITIVE', 'score': 0.6665104627609253},
#  {'label': 'POSITIVE', 'score': 0.9942693710327148},
#  {'label': 'NEGATIVE', 'score': 0.762010395526886},
#  {'label': 'POSITIVE', 'score': 0.9320820569992065},
#  {'label': 'NEUTRAL', 'score': 0.4850960671901703},
#  {'label': 'POSITIVE', 'score': 0.992121696472168},
#  {'label': 'NEGATIVE', 'score': 0.5957549214363098},
#  {'label': 'NEGATIVE', 'score': 0.8541562557220459},
#  {'label': 'NEUTRAL', 'score': 0.38347357511520386},
#  {'label': 'NEUTRAL', 'score': 0.4617331922054291},
#  {'label': 'NEGATIVE', 'score': 0.611070990562439},
#  {'label': 'POSITIVE', 'score': 0.9616348147392273},
#  {'label': 'NEGATIVE', 'score': 0.6220147609710693},
#  {'label': 'POSITIVE', 'score': 0.9865792393684387},
#  {'label': 'NEGATIVE', 'score': 0.6596310138702393},
#  {'label': 'NEUTRAL', 'score': 0.43364793062210083},
#  {'label': 'POSITIVE', 'score': 0.8940810561180115},
#  {'label': 'POSITIVE', 'score': 0.9946929812431335},
#  {'label': 'NEUTRAL', 'score': 0.43920212984085083},
#  {'label': 'POSITIVE', 'score': 0.9149748086929321},
#  {'label': 'POSITIVE', 'score': 0.9807503819465637},
#  {'label': 'NEGATIVE', 'score': 0.8499006628990173},
#  {'label': 'NEGATIVE', 'score': 0.6434764266014099},
#  {'label': 'POSITIVE', 'score': 0.9816299676895142},
#  {'label': 'NEGATIVE', 'score': 0.634477436542511},
#  {'label': 'POSITIVE', 'score': 0.9940633177757263},
#  {'label': 'NEGATIVE', 'score': 0.5406183004379272},
#  {'label': 'NEUTRAL', 'score': 0.6144888997077942},
#  {'label': 'NEGATIVE', 'score': 0.838476300239563},
#  {'label': 'POSITIVE', 'score': 0.9927371144294739},
#  {'label': 'NEUTRAL', 'score': 0.49538666009902954},
#  {'label': 'POSITIVE', 'score': 0.9937390089035034},
#  {'label': 'NEGATIVE', 'score': 0.8071797490119934},
#  {'label': 'POSITIVE', 'score': 0.9931915402412415},
#  {'label': 'NEGATIVE', 'score': 0.4889599084854126},
#  {'label': 'NEGATIVE', 'score': 0.48427098989486694},
#  {'label': 'NEGATIVE', 'score': 0.7880842685699463},
#  {'label': 'POSITIVE', 'score': 0.9812037348747253},
#  {'label': 'POSITIVE', 'score': 0.9485257267951965},
#  {'label': 'NEGATIVE', 'score': 0.6829308867454529},
#  {'label': 'NEGATIVE', 'score': 0.6844576001167297},
#  {'label': 'POSITIVE', 'score': 0.9914585947990417},
#  {'label': 'NEGATIVE', 'score': 0.8303834795951843},
#  {'label': 'NEGATIVE', 'score': 0.6062880754470825},
#  {'label': 'NEGATIVE', 'score': 0.7521247863769531},
#  {'label': 'POSITIVE', 'score': 0.9723736047744751},
#  {'label': 'NEGATIVE', 'score': 0.6118557453155518},
#  {'label': 'NEGATIVE', 'score': 0.670048713684082},
#  {'label': 'NEUTRAL', 'score': 0.5636386275291443},
#  {'label': 'POSITIVE', 'score': 0.6349337697029114},
#  {'label': 'POSITIVE', 'score': 0.5599820017814636},
#  {'label': 'POSITIVE', 'score': 0.9466426968574524},
#  {'label': 'NEGATIVE', 'score': 0.7829902172088623},
#  {'label': 'POSITIVE', 'score': 0.8891705274581909},
#  {'label': 'POSITIVE', 'score': 0.544579029083252},
#  {'label': 'NEGATIVE', 'score': 0.6149482727050781},
#  {'label': 'NEGATIVE', 'score': 0.8014318346977234},
#  {'label': 'NEUTRAL', 'score': 0.6453049778938293},
#  {'label': 'NEGATIVE', 'score': 0.5779342651367188},
#  {'label': 'NEGATIVE', 'score': 0.5955125093460083},
#  {'label': 'NEGATIVE', 'score': 0.78214430809021},
#  {'label': 'NEGATIVE', 'score': 0.7185166478157043},
#  {'label': 'NEGATIVE', 'score': 0.7468701004981995},
#  {'label': 'NEGATIVE', 'score': 0.6771878600120544},
#  {'label': 'NEGATIVE', 'score': 0.4833243787288666},
#  {'label': 'NEGATIVE', 'score': 0.4271329641342163},
#  {'label': 'NEGATIVE', 'score': 0.7400434613227844},
#  {'label': 'NEGATIVE', 'score': 0.607694149017334},
#  {'label': 'NEUTRAL', 'score': 0.5347272753715515},
#  {'label': 'NEGATIVE', 'score': 0.8513314723968506},
#  {'label': 'NEGATIVE', 'score': 0.540904700756073},
#  {'label': 'NEGATIVE', 'score': 0.49136701226234436},
#  {'label': 'NEGATIVE', 'score': 0.5603560209274292},
#  {'label': 'NEUTRAL', 'score': 0.5045283436775208},
#  {'label': 'NEGATIVE', 'score': 0.7668920755386353},
#  {'label': 'POSITIVE', 'score': 0.7511309385299683},
#  {'label': 'POSITIVE', 'score': 0.9883654117584229},
#  {'label': 'POSITIVE', 'score': 0.9929884076118469},
#  {'label': 'POSITIVE', 'score': 0.7632640600204468},
#  {'label': 'NEUTRAL', 'score': 0.5583401918411255},
#  {'label': 'POSITIVE', 'score': 0.9923402070999146},
#  {'label': 'POSITIVE', 'score': 0.8701830506324768},
#  {'label': 'POSITIVE', 'score': 0.42513740062713623},
#  {'label': 'NEUTRAL', 'score': 0.49077802896499634},
#  {'label': 'POSITIVE', 'score': 0.9223070740699768},
#  {'label': 'POSITIVE', 'score': 0.779894232749939},
#  {'label': 'NEUTRAL', 'score': 0.3828933537006378},
#  {'label': 'NEGATIVE', 'score': 0.6999567747116089},
#  {'label': 'NEGATIVE', 'score': 0.9204109311103821},
#  {'label': 'NEUTRAL', 'score': 0.5992678999900818},
#  {'label': 'NEGATIVE', 'score': 0.6934918165206909},
#  {'label': 'NEGATIVE', 'score': 0.8621010780334473},
#  {'label': 'NEUTRAL', 'score': 0.5747852325439453},
#  {'label': 'POSITIVE', 'score': 0.818385124206543},
#  {'label': 'POSITIVE', 'score': 0.9856007695198059},
#  {'label': 'NEGATIVE', 'score': 0.4977767765522003},
#  {'label': 'POSITIVE', 'score': 0.9839354753494263},
#  {'label': 'NEGATIVE', 'score': 0.6861099600791931},
#  {'label': 'NEUTRAL', 'score': 0.5443398952484131},
#  {'label': 'POSITIVE', 'score': 0.9930154085159302},
#  {'label': 'NEGATIVE', 'score': 0.8970478177070618},
#  {'label': 'NEUTRAL', 'score': 0.6269568204879761},
#  {'label': 'NEUTRAL', 'score': 0.39238113164901733},
#  {'label': 'POSITIVE', 'score': 0.7254237532615662},
#  {'label': 'NEGATIVE', 'score': 0.6760427355766296},
#  {'label': 'NEGATIVE', 'score': 0.6641973853111267},
#  {'label': 'NEGATIVE', 'score': 0.5762328505516052},
#  {'label': 'NEGATIVE', 'score': 0.81529700756073},
#  {'label': 'NEGATIVE', 'score': 0.6311305165290833},
#  {'label': 'POSITIVE', 'score': 0.975564181804657},
#  {'label': 'NEGATIVE', 'score': 0.6366556286811829},
#  {'label': 'NEGATIVE', 'score': 0.4245460629463196},
#  {'label': 'NEGATIVE', 'score': 0.5575456023216248},
#  {'label': 'POSITIVE', 'score': 0.9108932614326477},
#  {'label': 'POSITIVE', 'score': 0.9925140738487244},
#  {'label': 'POSITIVE', 'score': 0.60301673412323},
#  {'label': 'POSITIVE', 'score': 0.5628482699394226},
#  {'label': 'POSITIVE', 'score': 0.8199787139892578},
#  {'label': 'POSITIVE', 'score': 0.9900330901145935},
#  {'label': 'NEGATIVE', 'score': 0.5541843771934509},
#  {'label': 'POSITIVE', 'score': 0.953468382358551},
#  {'label': 'NEGATIVE', 'score': 0.6456423997879028},
#  {'label': 'NEUTRAL', 'score': 0.4995265305042267},
#  {'label': 'POSITIVE', 'score': 0.9930701851844788},
#  {'label': 'NEGATIVE', 'score': 0.60317462682724},
#  {'label': 'POSITIVE', 'score': 0.978293776512146},
#  {'label': 'POSITIVE', 'score': 0.9936835765838623},
#  {'label': 'NEGATIVE', 'score': 0.5767513513565063},
#  {'label': 'POSITIVE', 'score': 0.964181125164032},
#  {'label': 'POSITIVE', 'score': 0.9000799059867859},
#  {'label': 'POSITIVE', 'score': 0.5922112464904785},
#  {'label': 'NEGATIVE', 'score': 0.56085604429245},
#  {'label': 'POSITIVE', 'score': 0.9916484355926514},
#  {'label': 'NEUTRAL', 'score': 0.6670675277709961},
#  {'label': 'POSITIVE', 'score': 0.866701066493988},
#  {'label': 'NEGATIVE', 'score': 0.6836967468261719},
#  {'label': 'POSITIVE', 'score': 0.9933905601501465},
#  {'label': 'NEGATIVE', 'score': 0.7973393797874451},
#  {'label': 'POSITIVE', 'score': 0.9934946894645691},
#  {'label': 'NEUTRAL', 'score': 0.5029921531677246},
#  {'label': 'NEUTRAL', 'score': 0.6123890280723572},
#  {'label': 'POSITIVE', 'score': 0.993070662021637},
#  {'label': 'NEGATIVE', 'score': 0.576998770236969},
#  {'label': 'POSITIVE', 'score': 0.4613589942455292},
#  {'label': 'POSITIVE', 'score': 0.8888722062110901},
#  {'label': 'POSITIVE', 'score': 0.9098103642463684},
#  {'label': 'NEGATIVE', 'score': 0.7510015368461609},
#  {'label': 'POSITIVE', 'score': 0.9932304620742798},
#  {'label': 'POSITIVE', 'score': 0.9866423606872559},
#  {'label': 'NEUTRAL', 'score': 0.49965453147888184},
#  {'label': 'NEGATIVE', 'score': 0.8201707601547241},
#  {'label': 'POSITIVE', 'score': 0.9933682084083557},
#  {'label': 'POSITIVE', 'score': 0.978915274143219},
#  {'label': 'NEGATIVE', 'score': 0.7081352472305298},
#  {'label': 'NEGATIVE', 'score': 0.7889010906219482},
#  {'label': 'POSITIVE', 'score': 0.6844504475593567},
#  {'label': 'NEGATIVE', 'score': 0.6332427859306335},
#  {'label': 'POSITIVE', 'score': 0.9065216779708862},
#  {'label': 'POSITIVE', 'score': 0.9396858811378479},
#  {'label': 'NEUTRAL', 'score': 0.48923778533935547},
#  {'label': 'POSITIVE', 'score': 0.9902119040489197},
#  {'label': 'NEGATIVE', 'score': 0.5084184408187866},
#  {'label': 'POSITIVE', 'score': 0.9897375702857971},
#  {'label': 'NEGATIVE', 'score': 0.7148368954658508},
#  {'label': 'NEUTRAL', 'score': 0.459816038608551},
#  {'label': 'POSITIVE', 'score': 0.956630527973175},
#  {'label': 'NEGATIVE', 'score': 0.7823724746704102},
#  {'label': 'NEUTRAL', 'score': 0.4914449155330658},
#  {'label': 'POSITIVE', 'score': 0.946349024772644},
#  {'label': 'POSITIVE', 'score': 0.99277263879776},
#  {'label': 'NEGATIVE', 'score': 0.7218637466430664},
#  {'label': 'NEGATIVE', 'score': 0.5627796649932861},
#  {'label': 'POSITIVE', 'score': 0.6951335072517395},
#  {'label': 'POSITIVE', 'score': 0.5420722365379333},
#  {'label': 'NEGATIVE', 'score': 0.8279253244400024},
#  {'label': 'NEGATIVE', 'score': 0.6026948094367981},
#  {'label': 'NEGATIVE', 'score': 0.7307268381118774},
#  {'label': 'NEGATIVE', 'score': 0.8261411190032959},
#  {'label': 'NEGATIVE', 'score': 0.45626434683799744},
#  {'label': 'NEGATIVE', 'score': 0.6844800710678101},
#  {'label': 'POSITIVE', 'score': 0.9911527037620544},
#  {'label': 'POSITIVE', 'score': 0.9894821643829346},
#  {'label': 'NEGATIVE', 'score': 0.7544131278991699},
#  {'label': 'POSITIVE', 'score': 0.9720720052719116},
#  {'label': 'NEUTRAL', 'score': 0.5874270796775818},
#  {'label': 'POSITIVE', 'score': 0.9949526786804199},
#  {'label': 'NEGATIVE', 'score': 0.5050671696662903},
#  {'label': 'NEGATIVE', 'score': 0.7817034125328064},
#  {'label': 'NEGATIVE', 'score': 0.8892793655395508},
#  {'label': 'NEGATIVE', 'score': 0.699425220489502},
#  {'label': 'NEGATIVE', 'score': 0.7211949229240417},
#  {'label': 'POSITIVE', 'score': 0.9336692094802856},
#  {'label': 'POSITIVE', 'score': 0.6567192673683167},
#  {'label': 'NEUTRAL', 'score': 0.7106871604919434},
#  {'label': 'POSITIVE', 'score': 0.9939181804656982},
#  {'label': 'NEGATIVE', 'score': 0.7416077256202698},
#  {'label': 'NEGATIVE', 'score': 0.8466268181800842},
#  {'label': 'NEUTRAL', 'score': 0.4953957796096802},
#  {'label': 'POSITIVE', 'score': 0.7717499136924744},
#  {'label': 'NEGATIVE', 'score': 0.8545717597007751},
#  {'label': 'NEGATIVE', 'score': 0.7506291270256042},
#  {'label': 'NEGATIVE', 'score': 0.3626467287540436},
#  {'label': 'POSITIVE', 'score': 0.9932914972305298},
#  {'label': 'NEGATIVE', 'score': 0.941816508769989},
#  {'label': 'NEGATIVE', 'score': 0.8566128015518188},
#  {'label': 'NEUTRAL', 'score': 0.5188995003700256},
#  {'label': 'NEGATIVE', 'score': 0.5498234629631042},
#  {'label': 'NEGATIVE', 'score': 0.8146213293075562},
#  {'label': 'NEGATIVE', 'score': 0.645766019821167},
#  {'label': 'POSITIVE', 'score': 0.6373289227485657},
#  {'label': 'POSITIVE', 'score': 0.820324718952179},
#  {'label': 'POSITIVE', 'score': 0.9918020367622375},
#  {'label': 'NEGATIVE', 'score': 0.819844126701355},
#  {'label': 'NEUTRAL', 'score': 0.4975995123386383},
#  {'label': 'POSITIVE', 'score': 0.9927904605865479},
#  {'label': 'POSITIVE', 'score': 0.9917786717414856},
#  {'label': 'POSITIVE', 'score': 0.9934170246124268},
#  {'label': 'POSITIVE', 'score': 0.9854775071144104},
#  {'label': 'POSITIVE', 'score': 0.9505977630615234},
#  {'label': 'POSITIVE', 'score': 0.9925111532211304},
#  {'label': 'POSITIVE', 'score': 0.9737499952316284},
#  {'label': 'NEGATIVE', 'score': 0.5318173170089722},
#  {'label': 'NEUTRAL', 'score': 0.5286961793899536},
#  {'label': 'POSITIVE', 'score': 0.5078014731407166},
#  {'label': 'POSITIVE', 'score': 0.9934768080711365},
#  {'label': 'NEGATIVE', 'score': 0.841173529624939},
#  {'label': 'NEGATIVE', 'score': 0.5058440566062927},
#  {'label': 'NEGATIVE', 'score': 0.40444958209991455},
#  {'label': 'NEUTRAL', 'score': 0.511069655418396},
#  {'label': 'POSITIVE', 'score': 0.7222852110862732},
#  {'label': 'NEGATIVE', 'score': 0.677326500415802},
#  {'label': 'POSITIVE', 'score': 0.8146612048149109},
#  {'label': 'POSITIVE', 'score': 0.6938286423683167},
#  {'label': 'NEGATIVE', 'score': 0.7227753400802612},
#  {'label': 'NEUTRAL', 'score': 0.4634588956832886},
#  {'label': 'POSITIVE', 'score': 0.9822593927383423},
#  {'label': 'NEUTRAL', 'score': 0.3991730213165283},
#  {'label': 'NEGATIVE', 'score': 0.6427638530731201},
#  {'label': 'NEGATIVE', 'score': 0.7694659233093262},
#  {'label': 'NEGATIVE', 'score': 0.7747684121131897},
#  {'label': 'POSITIVE', 'score': 0.8925918936729431},
#  {'label': 'NEGATIVE', 'score': 0.8703523874282837},
#  {'label': 'NEGATIVE', 'score': 0.5337634086608887},
#  {'label': 'NEUTRAL', 'score': 0.4969267249107361},
#  {'label': 'POSITIVE', 'score': 0.6843944787979126},
#  {'label': 'NEGATIVE', 'score': 0.6204243898391724},
#  {'label': 'POSITIVE', 'score': 0.9320330619812012},
#  {'label': 'NEGATIVE', 'score': 0.893486499786377},
#  {'label': 'NEGATIVE', 'score': 0.8530653715133667},
#  {'label': 'NEGATIVE', 'score': 0.8206788897514343},
#  {'label': 'NEGATIVE', 'score': 0.6813602447509766},
#  {'label': 'NEGATIVE', 'score': 0.5606671571731567},
#  {'label': 'NEGATIVE', 'score': 0.7729939222335815},
#  {'label': 'NEGATIVE', 'score': 0.8301849365234375},
#  {'label': 'NEGATIVE', 'score': 0.4881550073623657},
#  {'label': 'NEGATIVE', 'score': 0.8023847341537476},
#  {'label': 'NEGATIVE', 'score': 0.6849226951599121},
#  {'label': 'POSITIVE', 'score': 0.9902094602584839},
#  {'label': 'NEUTRAL', 'score': 0.5202234983444214},
#  {'label': 'POSITIVE', 'score': 0.9065003991127014},
#  {'label': 'NEGATIVE', 'score': 0.4354080557823181},
#  {'label': 'NEUTRAL', 'score': 0.46955785155296326},
#  {'label': 'NEUTRAL', 'score': 0.5485007166862488},
#  {'label': 'NEGATIVE', 'score': 0.8297319412231445},
#  {'label': 'NEGATIVE', 'score': 0.7063185572624207},
#  {'label': 'POSITIVE', 'score': 0.5046719312667847},
#  {'label': 'POSITIVE', 'score': 0.9464465975761414},
#  {'label': 'NEGATIVE', 'score': 0.9472617506980896},
#  {'label': 'NEUTRAL', 'score': 0.4783687889575958},
#  {'label': 'NEGATIVE', 'score': 0.5960108041763306},
#  {'label': 'NEUTRAL', 'score': 0.4560900926589966},
#  {'label': 'POSITIVE', 'score': 0.992482602596283},
#  {'label': 'NEGATIVE', 'score': 0.5020820498466492},
#  {'label': 'NEGATIVE', 'score': 0.8746682405471802},
#  {'label': 'NEUTRAL', 'score': 0.5080036520957947},
#  {'label': 'NEGATIVE', 'score': 0.701025664806366},
#  {'label': 'POSITIVE', 'score': 0.9844116568565369},
#  {'label': 'NEGATIVE', 'score': 0.5996643900871277},
#  {'label': 'POSITIVE', 'score': 0.5389158129692078},
#  {'label': 'NEGATIVE', 'score': 0.7490970492362976},
#  {'label': 'NEGATIVE', 'score': 0.7712542414665222},
#  {'label': 'NEGATIVE', 'score': 0.5659569501876831},
#  {'label': 'POSITIVE', 'score': 0.9940515160560608},
#  {'label': 'NEGATIVE', 'score': 0.7063381671905518},
#  {'label': 'POSITIVE', 'score': 0.9922770261764526},
#  {'label': 'POSITIVE', 'score': 0.9944023489952087},
#  {'label': 'NEUTRAL', 'score': 0.5505083203315735},
#  {'label': 'POSITIVE', 'score': 0.9468072652816772},
#  {'label': 'NEUTRAL', 'score': 0.45714399218559265},
#  {'label': 'NEUTRAL', 'score': 0.5887271761894226},
#  {'label': 'NEUTRAL', 'score': 0.7131665945053101},
#  {'label': 'POSITIVE', 'score': 0.576576292514801},
#  {'label': 'POSITIVE', 'score': 0.9911739230155945},
#  {'label': 'POSITIVE', 'score': 0.9912318587303162},
#  {'label': 'POSITIVE', 'score': 0.9782422184944153},
#  {'label': 'POSITIVE', 'score': 0.7883817553520203},
#  {'label': 'NEGATIVE', 'score': 0.5260687470436096},
#  {'label': 'POSITIVE', 'score': 0.9918082356452942},
#  {'label': 'POSITIVE', 'score': 0.993183434009552},
#  {'label': 'POSITIVE', 'score': 0.9932117462158203},
#  {'label': 'POSITIVE', 'score': 0.8542293310165405},
#  {'label': 'POSITIVE', 'score': 0.9864856004714966},
#  {'label': 'POSITIVE', 'score': 0.8661565780639648},
#  {'label': 'NEGATIVE', 'score': 0.7608067393302917},
#  {'label': 'NEUTRAL', 'score': 0.47553151845932007},
#  {'label': 'NEGATIVE', 'score': 0.7013380527496338},
#  {'label': 'POSITIVE', 'score': 0.8050674200057983},
#  {'label': 'POSITIVE', 'score': 0.9931614398956299},
#  {'label': 'POSITIVE', 'score': 0.9637492895126343},
#  {'label': 'NEGATIVE', 'score': 0.40804043412208557},
#  {'label': 'POSITIVE', 'score': 0.9068849682807922},
#  {'label': 'POSITIVE', 'score': 0.583993673324585},
#  {'label': 'POSITIVE', 'score': 0.7964273691177368},
#  {'label': 'NEGATIVE', 'score': 0.6923186182975769},
#  {'label': 'NEUTRAL', 'score': 0.5334773659706116},
#  {'label': 'NEGATIVE', 'score': 0.8034435510635376},
#  {'label': 'NEGATIVE', 'score': 0.7865407466888428},
#  {'label': 'POSITIVE', 'score': 0.9888089299201965},
#  {'label': 'NEGATIVE', 'score': 0.5325839519500732},
#  {'label': 'NEUTRAL', 'score': 0.5194582939147949},
#  {'label': 'POSITIVE', 'score': 0.9906836748123169},
#  {'label': 'NEUTRAL', 'score': 0.5087212324142456},
#  {'label': 'POSITIVE', 'score': 0.9871576428413391},
#  {'label': 'POSITIVE', 'score': 0.9928061366081238},
#  {'label': 'NEUTRAL', 'score': 0.5570639967918396},
#  {'label': 'POSITIVE', 'score': 0.9926952123641968},
#  {'label': 'POSITIVE', 'score': 0.40939241647720337},
#  {'label': 'POSITIVE', 'score': 0.6158174276351929},
#  {'label': 'NEGATIVE', 'score': 0.9247477650642395},
#  {'label': 'NEGATIVE', 'score': 0.7485511302947998},
#  {'label': 'POSITIVE', 'score': 0.9809685945510864},
#  {'label': 'POSITIVE', 'score': 0.9745233058929443},
#  {'label': 'POSITIVE', 'score': 0.9640388488769531},
#  {'label': 'POSITIVE', 'score': 0.9907484650611877},
#  {'label': 'NEGATIVE', 'score': 0.8295888900756836},
#  {'label': 'NEUTRAL', 'score': 0.44544094800949097},
#  {'label': 'POSITIVE', 'score': 0.6253752708435059},
#  {'label': 'POSITIVE', 'score': 0.9757573008537292},
#  {'label': 'NEGATIVE', 'score': 0.814852774143219},
#  {'label': 'NEUTRAL', 'score': 0.4295082986354828},
#  {'label': 'NEGATIVE', 'score': 0.7515235543251038},
#  {'label': 'NEGATIVE', 'score': 0.6512665748596191},
#  {'label': 'POSITIVE', 'score': 0.9944737553596497},
#  {'label': 'NEGATIVE', 'score': 0.8452740907669067},
#  {'label': 'NEUTRAL', 'score': 0.5467822551727295},
#  {'label': 'NEGATIVE', 'score': 0.4729578197002411},
#  {'label': 'NEGATIVE', 'score': 0.8624321818351746},
#  {'label': 'NEGATIVE', 'score': 0.8638305068016052},
#  {'label': 'POSITIVE', 'score': 0.9936768412590027},
#  {'label': 'NEUTRAL', 'score': 0.5665894150733948},
#  {'label': 'NEGATIVE', 'score': 0.5994676351547241},
#  {'label': 'POSITIVE', 'score': 0.9922282099723816},
#  {'label': 'NEUTRAL', 'score': 0.5498747825622559},
#  {'label': 'POSITIVE', 'score': 0.9741408228874207},
#  {'label': 'NEGATIVE', 'score': 0.7316208481788635},
#  {'label': 'NEGATIVE', 'score': 0.6614125370979309},
#  {'label': 'POSITIVE', 'score': 0.9943004846572876},
#  {'label': 'POSITIVE', 'score': 0.982869565486908},
#  {'label': 'POSITIVE', 'score': 0.4307638704776764},
#  {'label': 'NEGATIVE', 'score': 0.6519742608070374},
#  {'label': 'POSITIVE', 'score': 0.9297724366188049},
#  {'label': 'POSITIVE', 'score': 0.990912914276123},
#  {'label': 'NEGATIVE', 'score': 0.5257825255393982},
#  {'label': 'NEUTRAL', 'score': 0.5190481543540955},
#  {'label': 'NEGATIVE', 'score': 0.6359188556671143},
#  {'label': 'POSITIVE', 'score': 0.9842613935470581},
#  {'label': 'NEUTRAL', 'score': 0.46475642919540405},
#  {'label': 'NEUTRAL', 'score': 0.6894587874412537},
#  {'label': 'NEGATIVE', 'score': 0.8736581802368164},
#  {'label': 'NEGATIVE', 'score': 0.5322253108024597},
#  {'label': 'NEGATIVE', 'score': 0.751956045627594},
#  {'label': 'POSITIVE', 'score': 0.4100397229194641},
#  {'label': 'NEGATIVE', 'score': 0.5594824552536011},
#  {'label': 'POSITIVE', 'score': 0.6015453934669495},
#  {'label': 'NEGATIVE', 'score': 0.866702139377594},
#  {'label': 'POSITIVE', 'score': 0.9876027703285217},
#  {'label': 'NEUTRAL', 'score': 0.6322954893112183},
#  {'label': 'NEGATIVE', 'score': 0.7734885215759277},
#  {'label': 'POSITIVE', 'score': 0.9918491840362549},
#  {'label': 'NEGATIVE', 'score': 0.9151674509048462},
#  {'label': 'NEGATIVE', 'score': 0.6085866689682007},
#  {'label': 'POSITIVE', 'score': 0.9917346239089966},
#  {'label': 'NEGATIVE', 'score': 0.839545726776123},
#  {'label': 'NEGATIVE', 'score': 0.7218955159187317},
#  {'label': 'NEUTRAL', 'score': 0.5111628174781799},
#  {'label': 'NEUTRAL', 'score': 0.5690967440605164},
#  {'label': 'POSITIVE', 'score': 0.45856162905693054},
#  {'label': 'NEGATIVE', 'score': 0.7668755054473877},
#  {'label': 'NEGATIVE', 'score': 0.7823649048805237},
#  {'label': 'NEUTRAL', 'score': 0.5265553593635559},
#  {'label': 'NEGATIVE', 'score': 0.7171759605407715},
#  {'label': 'POSITIVE', 'score': 0.8893659114837646},
#  {'label': 'POSITIVE', 'score': 0.8772050738334656},
#  {'label': 'NEGATIVE', 'score': 0.6259894371032715},
#  {'label': 'NEGATIVE', 'score': 0.8089902400970459},
#  {'label': 'NEGATIVE', 'score': 0.8331642150878906},
#  {'label': 'NEGATIVE', 'score': 0.7678908109664917},
#  {'label': 'POSITIVE', 'score': 0.993398904800415},
#  {'label': 'POSITIVE', 'score': 0.9889609217643738},
#  {'label': 'NEUTRAL', 'score': 0.5212744474411011},
#  {'label': 'NEGATIVE', 'score': 0.7465949058532715},
#  {'label': 'NEUTRAL', 'score': 0.7040697932243347},
#  {'label': 'NEUTRAL', 'score': 0.5426801443099976},
#  {'label': 'POSITIVE', 'score': 0.9921637773513794},
#  {'label': 'NEGATIVE', 'score': 0.7531835436820984},
#  {'label': 'NEGATIVE', 'score': 0.7905132174491882},
#  {'label': 'NEGATIVE', 'score': 0.7602381706237793},
#  {'label': 'POSITIVE', 'score': 0.9803722500801086},
#  {'label': 'NEGATIVE', 'score': 0.6269375681877136},
#  {'label': 'NEGATIVE', 'score': 0.8137080073356628},
#  {'label': 'POSITIVE', 'score': 0.992956280708313},
#  {'label': 'POSITIVE', 'score': 0.720221996307373},
#  {'label': 'POSITIVE', 'score': 0.993625283241272},
#  {'label': 'POSITIVE', 'score': 0.6090086102485657},
#  {'label': 'NEGATIVE', 'score': 0.8108434081077576},
#  {'label': 'NEGATIVE', 'score': 0.6643038392066956},
#  {'label': 'NEUTRAL', 'score': 0.5025246143341064},
#  {'label': 'NEUTRAL', 'score': 0.4901876747608185},
#  {'label': 'NEGATIVE', 'score': 0.6364027261734009},
#  {'label': 'NEUTRAL', 'score': 0.5400105714797974},
#  {'label': 'POSITIVE', 'score': 0.47434258460998535},
#  {'label': 'POSITIVE', 'score': 0.6007586717605591},
#  {'label': 'NEGATIVE', 'score': 0.7036275863647461},
#  {'label': 'NEGATIVE', 'score': 0.8789259195327759},
#  {'label': 'POSITIVE', 'score': 0.9842925667762756},
#  {'label': 'POSITIVE', 'score': 0.9815034866333008},
#  {'label': 'POSITIVE', 'score': 0.9933217167854309},
#  {'label': 'POSITIVE', 'score': 0.4600677788257599},
#  {'label': 'NEUTRAL', 'score': 0.5833556056022644},
#  {'label': 'POSITIVE', 'score': 0.973742663860321},
#  {'label': 'NEGATIVE', 'score': 0.7386907935142517},
#  {'label': 'NEGATIVE', 'score': 0.8598021268844604},
#  {'label': 'POSITIVE', 'score': 0.9533693194389343},
#  {'label': 'POSITIVE', 'score': 0.9688102006912231},
#  {'label': 'NEGATIVE', 'score': 0.382127970457077},
#  {'label': 'NEGATIVE', 'score': 0.8734330534934998},
#  {'label': 'NEGATIVE', 'score': 0.8071529269218445},
#  {'label': 'POSITIVE', 'score': 0.993683934211731},
#  {'label': 'NEGATIVE', 'score': 0.4990372657775879},
#  {'label': 'NEGATIVE', 'score': 0.6890764236450195},
#  {'label': 'POSITIVE', 'score': 0.9844675660133362},
#  {'label': 'POSITIVE', 'score': 0.5683845281600952},
#  {'label': 'NEUTRAL', 'score': 0.7564170956611633},
#  {'label': 'POSITIVE', 'score': 0.5674343109130859},
#  {'label': 'POSITIVE', 'score': 0.977967381477356},
#  {'label': 'NEGATIVE', 'score': 0.5252475738525391},
#  {'label': 'NEGATIVE', 'score': 0.5679454803466797},
#  {'label': 'NEGATIVE', 'score': 0.5713815689086914},
#  {'label': 'NEGATIVE', 'score': 0.6771759390830994},
#  {'label': 'POSITIVE', 'score': 0.878032386302948},
#  {'label': 'NEGATIVE', 'score': 0.5904500484466553},
#  {'label': 'NEGATIVE', 'score': 0.923352062702179},
#  {'label': 'POSITIVE', 'score': 0.9913290739059448},
#  {'label': 'NEUTRAL', 'score': 0.6250112652778625},
#  {'label': 'NEUTRAL', 'score': 0.4818606376647949},
#  {'label': 'NEGATIVE', 'score': 0.7365930080413818},
#  {'label': 'NEGATIVE', 'score': 0.8032820820808411},
#  {'label': 'NEUTRAL', 'score': 0.5719563961029053},
#  {'label': 'POSITIVE', 'score': 0.9586260914802551},
#  {'label': 'POSITIVE', 'score': 0.7381680011749268},
#  {'label': 'NEGATIVE', 'score': 0.5735887289047241},
#  {'label': 'POSITIVE', 'score': 0.9879872798919678},
#  {'label': 'NEUTRAL', 'score': 0.39291682839393616},
#  {'label': 'POSITIVE', 'score': 0.9244704842567444},
#  {'label': 'NEGATIVE', 'score': 0.7901539206504822},
#  {'label': 'NEUTRAL', 'score': 0.4015987813472748},
#  {'label': 'NEUTRAL', 'score': 0.4727495610713959},
#  {'label': 'NEGATIVE', 'score': 0.663353443145752},
#  {'label': 'POSITIVE', 'score': 0.7085751891136169},
#  {'label': 'POSITIVE', 'score': 0.9834223985671997},
#  {'label': 'NEGATIVE', 'score': 0.899677574634552},
#  {'label': 'POSITIVE', 'score': 0.7781534790992737},
#  {'label': 'POSITIVE', 'score': 0.7680078744888306},
#  {'label': 'POSITIVE', 'score': 0.9837506413459778},
#  {'label': 'NEUTRAL', 'score': 0.6807131767272949},
#  {'label': 'NEUTRAL', 'score': 0.545062780380249},
#  {'label': 'POSITIVE', 'score': 0.986754834651947},
#  {'label': 'POSITIVE', 'score': 0.5898612141609192},
#  {'label': 'POSITIVE', 'score': 0.9914869070053101},
#  {'label': 'NEUTRAL', 'score': 0.5909456014633179},
#  {'label': 'NEUTRAL', 'score': 0.5208885073661804},
#  {'label': 'NEGATIVE', 'score': 0.8629786968231201},
#  {'label': 'POSITIVE', 'score': 0.9930692911148071},
#  {'label': 'NEGATIVE', 'score': 0.6943018436431885},
#  {'label': 'NEUTRAL', 'score': 0.4785238206386566},
#  {'label': 'POSITIVE', 'score': 0.5926559567451477},
#  {'label': 'NEGATIVE', 'score': 0.5203523635864258},
#  {'label': 'NEGATIVE', 'score': 0.6859205365180969},
#  {'label': 'POSITIVE', 'score': 0.9178465604782104},
#  {'label': 'NEGATIVE', 'score': 0.3726211488246918},
#  {'label': 'NEGATIVE', 'score': 0.5720937848091125},
#  {'label': 'NEGATIVE', 'score': 0.6422020792961121},
#  {'label': 'NEGATIVE', 'score': 0.4963676333427429},
#  {'label': 'NEGATIVE', 'score': 0.8255078196525574},
#  {'label': 'NEGATIVE', 'score': 0.7745360732078552},
#  {'label': 'POSITIVE', 'score': 0.8256845474243164},
#  {'label': 'NEGATIVE', 'score': 0.8037683367729187},
#  {'label': 'NEUTRAL', 'score': 0.578665018081665},
#  {'label': 'POSITIVE', 'score': 0.9813396334648132},
#  {'label': 'NEGATIVE', 'score': 0.7113808989524841},
#  {'label': 'POSITIVE', 'score': 0.9514216780662537},
#  {'label': 'NEUTRAL', 'score': 0.4991828501224518},
#  {'label': 'POSITIVE', 'score': 0.700507402420044},
#  {'label': 'NEGATIVE', 'score': 0.6005574464797974},
#  {'label': 'NEGATIVE', 'score': 0.710315465927124},
#  {'label': 'POSITIVE', 'score': 0.9336037635803223},
#  {'label': 'NEGATIVE', 'score': 0.38322028517723083},
#  {'label': 'POSITIVE', 'score': 0.9915829300880432},
#  {'label': 'NEGATIVE', 'score': 0.6620851159095764},
#  {'label': 'NEUTRAL', 'score': 0.6394960284233093},
#  {'label': 'NEGATIVE', 'score': 0.5748043060302734},
#  {'label': 'NEGATIVE', 'score': 0.8580491542816162},
#  {'label': 'NEGATIVE', 'score': 0.5826020240783691},
#  {'label': 'POSITIVE', 'score': 0.8935751914978027},
#  {'label': 'NEGATIVE', 'score': 0.545595645904541},
#  {'label': 'POSITIVE', 'score': 0.5533332824707031},
#  {'label': 'POSITIVE', 'score': 0.9709779024124146},
#  {'label': 'POSITIVE', 'score': 0.9189406037330627},
#  {'label': 'NEGATIVE', 'score': 0.6021732091903687},
#  {'label': 'NEGATIVE', 'score': 0.6821757555007935},
#  {'label': 'NEUTRAL', 'score': 0.6633939743041992},
#  {'label': 'POSITIVE', 'score': 0.5671424865722656},
#  {'label': 'POSITIVE', 'score': 0.9879976511001587},
#  {'label': 'NEGATIVE', 'score': 0.6022061109542847},
#  {'label': 'NEGATIVE', 'score': 0.7322360873222351},
#  {'label': 'POSITIVE', 'score': 0.47203895449638367},
#  {'label': 'NEGATIVE', 'score': 0.8412259221076965},
#  {'label': 'NEGATIVE', 'score': 0.7556596398353577},
#  {'label': 'NEUTRAL', 'score': 0.524590253829956},
#  {'label': 'NEGATIVE', 'score': 0.8112955093383789},
#  {'label': 'POSITIVE', 'score': 0.994240403175354},
#  {'label': 'POSITIVE', 'score': 0.9944433569908142},
#  {'label': 'POSITIVE', 'score': 0.9569605588912964},
#  {'label': 'POSITIVE', 'score': 0.5527211427688599},
#  {'label': 'NEGATIVE', 'score': 0.9023400545120239},
#  {'label': 'POSITIVE', 'score': 0.9313976764678955},
#  {'label': 'NEUTRAL', 'score': 0.5825956463813782},
#  {'label': 'NEGATIVE', 'score': 0.48913541436195374},
#  {'label': 'POSITIVE', 'score': 0.9918320775032043},
#  {'label': 'NEUTRAL', 'score': 0.4752473533153534},
#  {'label': 'POSITIVE', 'score': 0.7286375761032104},
#  {'label': 'NEUTRAL', 'score': 0.6127716302871704},
#  {'label': 'POSITIVE', 'score': 0.9636467099189758},
#  {'label': 'NEGATIVE', 'score': 0.8554590344429016},
#  {'label': 'NEGATIVE', 'score': 0.6332172751426697},
#  {'label': 'POSITIVE', 'score': 0.6208905577659607},
#  {'label': 'NEGATIVE', 'score': 0.8737845420837402},
#  {'label': 'POSITIVE', 'score': 0.45472806692123413},
#  {'label': 'POSITIVE', 'score': 0.7100241184234619},
#  {'label': 'POSITIVE', 'score': 0.9900257587432861},
#  {'label': 'POSITIVE', 'score': 0.9944979548454285},
#  {'label': 'NEGATIVE', 'score': 0.3984064757823944},
#  {'label': 'NEGATIVE', 'score': 0.8567505478858948},
#  {'label': 'POSITIVE', 'score': 0.9613872766494751},
#  {'label': 'NEUTRAL', 'score': 0.6854727864265442},
#  {'label': 'NEGATIVE', 'score': 0.5339130759239197},
#  {'label': 'NEGATIVE', 'score': 0.8723965287208557},
#  {'label': 'NEUTRAL', 'score': 0.7112566232681274},
#  {'label': 'NEGATIVE', 'score': 0.5328095555305481},
#  {'label': 'NEGATIVE', 'score': 0.48042699694633484},
#  {'label': 'POSITIVE', 'score': 0.8110905885696411},
#  {'label': 'NEGATIVE', 'score': 0.5164603590965271},
#  {'label': 'POSITIVE', 'score': 0.9363285899162292},
#  {'label': 'POSITIVE', 'score': 0.9574203491210938},
#  {'label': 'NEGATIVE', 'score': 0.5528059005737305},
#  {'label': 'POSITIVE', 'score': 0.9718492031097412},
#  {'label': 'POSITIVE', 'score': 0.8825119733810425},
#  {'label': 'NEUTRAL', 'score': 0.44488298892974854},
#  {'label': 'NEGATIVE', 'score': 0.5876674652099609},
#  {'label': 'NEGATIVE', 'score': 0.6987727284431458},
#  {'label': 'NEUTRAL', 'score': 0.4893246591091156},
#  {'label': 'NEGATIVE', 'score': 0.6502169370651245},
#  {'label': 'NEGATIVE', 'score': 0.5395285487174988},
#  {'label': 'NEGATIVE', 'score': 0.7421324849128723},
#  {'label': 'POSITIVE', 'score': 0.9819757342338562},
#  {'label': 'POSITIVE', 'score': 0.7740126848220825},
#  {'label': 'POSITIVE', 'score': 0.9155731797218323},
#  {'label': 'NEGATIVE', 'score': 0.7528281211853027},
#  {'label': 'POSITIVE', 'score': 0.8773003220558167},
#  {'label': 'NEGATIVE', 'score': 0.6402989625930786},
#  {'label': 'NEGATIVE', 'score': 0.5479193329811096},
#  {'label': 'POSITIVE', 'score': 0.8704469799995422},
#  {'label': 'POSITIVE', 'score': 0.9920423626899719},
#  {'label': 'NEGATIVE', 'score': 0.7028691172599792},
#  {'label': 'POSITIVE', 'score': 0.9919151067733765},
#  {'label': 'NEGATIVE', 'score': 0.84675133228302},
#  {'label': 'POSITIVE', 'score': 0.9893118739128113},
#  {'label': 'POSITIVE', 'score': 0.8091116547584534},
#  {'label': 'NEUTRAL', 'score': 0.5196524858474731},
#  {'label': 'POSITIVE', 'score': 0.992946207523346},
#  {'label': 'NEGATIVE', 'score': 0.6500616073608398},
#  {'label': 'NEGATIVE', 'score': 0.5085185766220093},
#  {'label': 'POSITIVE', 'score': 0.8640439510345459},
#  {'label': 'NEUTRAL', 'score': 0.5381408333778381},
#  {'label': 'NEGATIVE', 'score': 0.6345301866531372},
#  {'label': 'POSITIVE', 'score': 0.9930890202522278},
#  {'label': 'POSITIVE', 'score': 0.7317536473274231},
#  {'label': 'POSITIVE', 'score': 0.9937619566917419},
#  {'label': 'POSITIVE', 'score': 0.9832465052604675},
#  {'label': 'POSITIVE', 'score': 0.6002904772758484},
#  {'label': 'POSITIVE', 'score': 0.44588810205459595},
#  {'label': 'POSITIVE', 'score': 0.9091442823410034},
#  {'label': 'NEUTRAL', 'score': 0.5746859908103943},
#  {'label': 'NEGATIVE', 'score': 0.7036893963813782},
#  {'label': 'POSITIVE', 'score': 0.5229347944259644},
#  {'label': 'POSITIVE', 'score': 0.9933491349220276},
#  {'label': 'POSITIVE', 'score': 0.9828267097473145},
#  {'label': 'NEUTRAL', 'score': 0.49500906467437744},
#  {'label': 'POSITIVE', 'score': 0.8731033802032471},
#  {'label': 'NEUTRAL', 'score': 0.5842808485031128},
#  {'label': 'NEUTRAL', 'score': 0.5468807220458984},
#  {'label': 'NEUTRAL', 'score': 0.5287615656852722},
#  {'label': 'NEGATIVE', 'score': 0.5314003825187683},
#  {'label': 'POSITIVE', 'score': 0.8314223289489746},
#  {'label': 'POSITIVE', 'score': 0.6639816761016846},
#  {'label': 'NEGATIVE', 'score': 0.8088610172271729},
#  {'label': 'NEUTRAL', 'score': 0.4120768904685974},
#  {'label': 'NEGATIVE', 'score': 0.8644182682037354},
#  {'label': 'NEUTRAL', 'score': 0.6450566053390503},
#  {'label': 'NEGATIVE', 'score': 0.610573410987854},
#  {'label': 'POSITIVE', 'score': 0.6603580117225647},
#  {'label': 'POSITIVE', 'score': 0.9938821792602539},
#  {'label': 'POSITIVE', 'score': 0.9939593076705933},
#  {'label': 'NEGATIVE', 'score': 0.6390215158462524},
#  {'label': 'NEGATIVE', 'score': 0.5032691955566406},
#  {'label': 'NEGATIVE', 'score': 0.5901175737380981},
#  {'label': 'POSITIVE', 'score': 0.6372660398483276},
#  {'label': 'NEGATIVE', 'score': 0.4794125258922577},
#  {'label': 'NEGATIVE', 'score': 0.6519693732261658},
#  {'label': 'NEUTRAL', 'score': 0.5501141548156738},
#  {'label': 'POSITIVE', 'score': 0.9748456478118896},
#  {'label': 'NEGATIVE', 'score': 0.8203936815261841},
#  {'label': 'POSITIVE', 'score': 0.8882073760032654},
#  {'label': 'POSITIVE', 'score': 0.979015588760376},
#  {'label': 'POSITIVE', 'score': 0.5331845283508301},
#  {'label': 'POSITIVE', 'score': 0.9925716519355774},
#  {'label': 'NEGATIVE', 'score': 0.6253984570503235},
#  {'label': 'POSITIVE', 'score': 0.7327224612236023},
#  {'label': 'NEGATIVE', 'score': 0.7949986457824707},
#  {'label': 'NEGATIVE', 'score': 0.46826857328414917},
#  {'label': 'POSITIVE', 'score': 0.976619303226471},
#  {'label': 'POSITIVE', 'score': 0.8843393921852112},
#  {'label': 'NEUTRAL', 'score': 0.5428159832954407},
#  {'label': 'NEGATIVE', 'score': 0.5811361074447632},
#  {'label': 'NEGATIVE', 'score': 0.5819738507270813},
#  {'label': 'NEGATIVE', 'score': 0.41917407512664795},
#  {'label': 'POSITIVE', 'score': 0.9829659461975098},
#  {'label': 'POSITIVE', 'score': 0.8493296504020691},
#  {'label': 'NEUTRAL', 'score': 0.41334331035614014},
#  {'label': 'POSITIVE', 'score': 0.9946430921554565},
#  {'label': 'NEUTRAL', 'score': 0.5278412699699402},
#  {'label': 'NEGATIVE', 'score': 0.5231712460517883},
#  {'label': 'NEGATIVE', 'score': 0.6900492906570435},
#  {'label': 'NEGATIVE', 'score': 0.8577931523323059},
#  {'label': 'POSITIVE', 'score': 0.488020122051239},
#  {'label': 'POSITIVE', 'score': 0.9882036447525024},
#  {'label': 'POSITIVE', 'score': 0.9207136034965515},
#  {'label': 'NEGATIVE', 'score': 0.5029885768890381},
#  {'label': 'POSITIVE', 'score': 0.9931314587593079},
#  {'label': 'NEUTRAL', 'score': 0.641443133354187},
#  {'label': 'NEUTRAL', 'score': 0.5585212111473083},
#  {'label': 'POSITIVE', 'score': 0.9927680492401123},
#  {'label': 'NEGATIVE', 'score': 0.8321772813796997},
#  {'label': 'NEUTRAL', 'score': 0.702107846736908},
#  {'label': 'NEGATIVE', 'score': 0.9083780646324158},
#  {'label': 'NEUTRAL', 'score': 0.6828575730323792},
#  {'label': 'NEGATIVE', 'score': 0.580756664276123},
#  {'label': 'NEUTRAL', 'score': 0.6643372774124146},
#  {'label': 'NEGATIVE', 'score': 0.7540906071662903},
#  {'label': 'NEGATIVE', 'score': 0.571751058101654},
#  {'label': 'POSITIVE', 'score': 0.9943469166755676},
#  {'label': 'NEUTRAL', 'score': 0.5496346950531006},
#  {'label': 'NEUTRAL', 'score': 0.6523838043212891},
#  {'label': 'POSITIVE', 'score': 0.9919300675392151},
#  {'label': 'NEUTRAL', 'score': 0.5224334001541138},
#  {'label': 'POSITIVE', 'score': 0.42711228132247925},
#  {'label': 'NEUTRAL', 'score': 0.5925276875495911},
#  {'label': 'POSITIVE', 'score': 0.9842365980148315},
#  {'label': 'NEGATIVE', 'score': 0.5068842768669128},
#  {'label': 'NEGATIVE', 'score': 0.860566258430481},
#  {'label': 'NEGATIVE', 'score': 0.508234441280365},
#  {'label': 'NEGATIVE', 'score': 0.6707893013954163},
#  {'label': 'NEGATIVE', 'score': 0.7650662660598755},
#  {'label': 'NEGATIVE', 'score': 0.7183594107627869},
#  {'label': 'NEGATIVE', 'score': 0.7001197338104248},
#  {'label': 'POSITIVE', 'score': 0.9918463826179504},
#  {'label': 'NEGATIVE', 'score': 0.6439117789268494},
#  {'label': 'NEUTRAL', 'score': 0.481410950422287},
#  {'label': 'NEUTRAL', 'score': 0.4406720697879791},
#  {'label': 'NEGATIVE', 'score': 0.8039216995239258},
#  {'label': 'POSITIVE', 'score': 0.5858455896377563},
#  {'label': 'NEGATIVE', 'score': 0.47884106636047363},
#  {'label': 'NEGATIVE', 'score': 0.5787922143936157},
#  {'label': 'POSITIVE', 'score': 0.4352898895740509},
#  {'label': 'POSITIVE', 'score': 0.986695408821106},
#  {'label': 'NEGATIVE', 'score': 0.6572842001914978},
#  {'label': 'POSITIVE', 'score': 0.6339142918586731},
#  {'label': 'NEGATIVE', 'score': 0.7658496499061584},
#  {'label': 'NEGATIVE', 'score': 0.8055797219276428},
#  {'label': 'NEGATIVE', 'score': 0.9303528070449829},
#  {'label': 'POSITIVE', 'score': 0.5935791730880737},
#  {'label': 'NEGATIVE', 'score': 0.5676128268241882},
#  {'label': 'POSITIVE', 'score': 0.9931522607803345},
#  {'label': 'POSITIVE', 'score': 0.7473705410957336},
#  {'label': 'POSITIVE', 'score': 0.9899069666862488},
#  {'label': 'NEGATIVE', 'score': 0.6917198300361633},
#  {'label': 'POSITIVE', 'score': 0.9945758581161499},
#  {'label': 'NEGATIVE', 'score': 0.5592401623725891},
#  {'label': 'POSITIVE', 'score': 0.9733006954193115},
#  {'label': 'POSITIVE', 'score': 0.9389693140983582},
#  {'label': 'NEGATIVE', 'score': 0.6062852740287781},
#  {'label': 'POSITIVE', 'score': 0.9906298518180847},
#  {'label': 'NEGATIVE', 'score': 0.6983862519264221},
#  {'label': 'POSITIVE', 'score': 0.9833775758743286},
#  {'label': 'POSITIVE', 'score': 0.8296478986740112},
#  {'label': 'NEGATIVE', 'score': 0.849846363067627},
#  {'label': 'NEUTRAL', 'score': 0.6205106973648071},
#  {'label': 'NEUTRAL', 'score': 0.49980926513671875},
#  {'label': 'NEGATIVE', 'score': 0.6127004623413086},
#  {'label': 'NEGATIVE', 'score': 0.7953158020973206},
#  {'label': 'NEGATIVE', 'score': 0.6933320760726929},
#  {'label': 'NEGATIVE', 'score': 0.4920608401298523},
#  {'label': 'POSITIVE', 'score': 0.9935492873191833},
#  {'label': 'NEGATIVE', 'score': 0.680505096912384},
#  {'label': 'POSITIVE', 'score': 0.9081903100013733},
#  {'label': 'POSITIVE', 'score': 0.994266927242279},
#  {'label': 'POSITIVE', 'score': 0.985047459602356},
#  {'label': 'POSITIVE', 'score': 0.9923151135444641},
#  {'label': 'POSITIVE', 'score': 0.9927942156791687},
#  {'label': 'POSITIVE', 'score': 0.8496572375297546},
#  {'label': 'NEUTRAL', 'score': 0.4531574249267578},
#  {'label': 'POSITIVE', 'score': 0.8735523819923401},
#  {'label': 'POSITIVE', 'score': 0.8085504174232483},
#  {'label': 'NEUTRAL', 'score': 0.45910993218421936},
#  {'label': 'NEGATIVE', 'score': 0.650797426700592},
#  {'label': 'NEGATIVE', 'score': 0.593961238861084},
#  {'label': 'NEUTRAL', 'score': 0.50555819272995},
#  {'label': 'NEGATIVE', 'score': 0.5276283621788025},
#  {'label': 'NEUTRAL', 'score': 0.5835614204406738},
#  {'label': 'POSITIVE', 'score': 0.9850672483444214},
#  {'label': 'NEGATIVE', 'score': 0.8905887603759766},
#  {'label': 'NEGATIVE', 'score': 0.668950080871582},
#  {'label': 'NEGATIVE', 'score': 0.6432669758796692},
#  {'label': 'NEGATIVE', 'score': 0.4779004156589508},
#  {'label': 'POSITIVE', 'score': 0.9921671748161316},
#  {'label': 'NEGATIVE', 'score': 0.5542033910751343},
#  {'label': 'POSITIVE', 'score': 0.6815649271011353},
#  {'label': 'NEGATIVE', 'score': 0.9035710096359253},
#  {'label': 'NEGATIVE', 'score': 0.8314085602760315},
#  {'label': 'NEGATIVE', 'score': 0.6306763291358948},
#  {'label': 'POSITIVE', 'score': 0.9661098122596741},
#  {'label': 'POSITIVE', 'score': 0.9901406168937683},
#  {'label': 'NEUTRAL', 'score': 0.5506183505058289},
#  {'label': 'POSITIVE', 'score': 0.9831682443618774},
#  {'label': 'POSITIVE', 'score': 0.9549282193183899},
#  {'label': 'POSITIVE', 'score': 0.35904166102409363},
#  {'label': 'NEUTRAL', 'score': 0.5803062915802002},
#  {'label': 'NEUTRAL', 'score': 0.42162176966667175},
#  {'label': 'NEUTRAL', 'score': 0.5155141949653625},
#  {'label': 'NEUTRAL', 'score': 0.804006040096283},
#  {'label': 'NEGATIVE', 'score': 0.5861228108406067},
#  {'label': 'NEGATIVE', 'score': 0.5985314846038818},
#  {'label': 'POSITIVE', 'score': 0.9874883890151978},
#  {'label': 'NEGATIVE', 'score': 0.7244990468025208},
#  {'label': 'POSITIVE', 'score': 0.9948300719261169},
#  {'label': 'NEGATIVE', 'score': 0.657236635684967},
#  {'label': 'NEGATIVE', 'score': 0.9676755666732788},
#  {'label': 'NEGATIVE', 'score': 0.8648635149002075},
#  {'label': 'POSITIVE', 'score': 0.8354926705360413},
#  {'label': 'NEGATIVE', 'score': 0.5248969197273254},
#  {'label': 'NEGATIVE', 'score': 0.6165197491645813},
#  {'label': 'POSITIVE', 'score': 0.8563731908798218},
#  {'label': 'NEGATIVE', 'score': 0.5929619073867798},
#  {'label': 'NEUTRAL', 'score': 0.43506959080696106},
#  {'label': 'POSITIVE', 'score': 0.9262515306472778},
#  {'label': 'NEGATIVE', 'score': 0.5293819308280945},
#  {'label': 'NEGATIVE', 'score': 0.9082891345024109},
#  {'label': 'POSITIVE', 'score': 0.9929976463317871},
#  {'label': 'NEGATIVE', 'score': 0.8393165469169617},
#  {'label': 'NEUTRAL', 'score': 0.62553471326828},
#  {'label': 'NEUTRAL', 'score': 0.5688170790672302},
#  {'label': 'NEUTRAL', 'score': 0.5033841729164124},
#  {'label': 'NEGATIVE', 'score': 0.7647051811218262},
#  {'label': 'POSITIVE', 'score': 0.9919342994689941},
#  {'label': 'NEGATIVE', 'score': 0.7014155387878418},
#  {'label': 'POSITIVE', 'score': 0.9898256659507751},
#  {'label': 'NEGATIVE', 'score': 0.5175167918205261},
#  {'label': 'POSITIVE', 'score': 0.3839069604873657},
#  {'label': 'NEGATIVE', 'score': 0.855252206325531},
#  {'label': 'POSITIVE', 'score': 0.9617937207221985},
#  {'label': 'POSITIVE', 'score': 0.6379358768463135},
#  {'label': 'POSITIVE', 'score': 0.9930288195610046},
#  {'label': 'POSITIVE', 'score': 0.5230913758277893},
#  {'label': 'NEUTRAL', 'score': 0.5976150631904602},
#  {'label': 'NEGATIVE', 'score': 0.6014328002929688},
#  {'label': 'NEUTRAL', 'score': 0.5578838586807251},
#  {'label': 'NEGATIVE', 'score': 0.527747392654419},
#  {'label': 'NEUTRAL', 'score': 0.3812413513660431},
#  {'label': 'NEGATIVE', 'score': 0.7525140047073364},
#  {'label': 'NEGATIVE', 'score': 0.6742631196975708},
#  {'label': 'NEGATIVE', 'score': 0.7216291427612305},
#  {'label': 'NEGATIVE', 'score': 0.6164214015007019},
#  {'label': 'POSITIVE', 'score': 0.6267539858818054},
#  {'label': 'NEGATIVE', 'score': 0.7980411648750305},
#  {'label': 'POSITIVE', 'score': 0.98736572265625},
#  {'label': 'POSITIVE', 'score': 0.8008447885513306},
#  {'label': 'POSITIVE', 'score': 0.9941548705101013},
#  {'label': 'NEGATIVE', 'score': 0.598442792892456},
#  {'label': 'POSITIVE', 'score': 0.5872548818588257},
#  {'label': 'NEGATIVE', 'score': 0.6079534888267517},
#  {'label': 'NEGATIVE', 'score': 0.971235990524292},
#  {'label': 'POSITIVE', 'score': 0.5836593508720398},
#  {'label': 'POSITIVE', 'score': 0.9939690828323364},
#  {'label': 'POSITIVE', 'score': 0.8072952628135681},
#  {'label': 'NEUTRAL', 'score': 0.551836371421814},
#  {'label': 'NEUTRAL', 'score': 0.5324395298957825},
#  {'label': 'NEUTRAL', 'score': 0.7752952575683594},
#  {'label': 'POSITIVE', 'score': 0.6544141173362732},
#  {'label': 'POSITIVE', 'score': 0.9636269807815552},
#  {'label': 'POSITIVE', 'score': 0.9767136573791504},
#  {'label': 'NEUTRAL', 'score': 0.4458211362361908},
#  {'label': 'POSITIVE', 'score': 0.9941816926002502},
#  {'label': 'NEUTRAL', 'score': 0.4885920286178589},
#  {'label': 'NEUTRAL', 'score': 0.5483922362327576},
#  {'label': 'NEGATIVE', 'score': 0.5931603908538818},
#  {'label': 'POSITIVE', 'score': 0.9399202466011047},
#  {'label': 'POSITIVE', 'score': 0.9907377362251282},
#  {'label': 'NEUTRAL', 'score': 0.5165620446205139},
#  {'label': 'NEGATIVE', 'score': 0.5309709906578064},
#  {'label': 'NEGATIVE', 'score': 0.7536795139312744},
#  {'label': 'NEUTRAL', 'score': 0.6264327764511108},
#  {'label': 'POSITIVE', 'score': 0.5344869494438171},
#  {'label': 'NEGATIVE', 'score': 0.6401848196983337},
#  {'label': 'NEUTRAL', 'score': 0.4631768465042114},
#  {'label': 'NEGATIVE', 'score': 0.9132625460624695},
#  {'label': 'NEGATIVE', 'score': 0.6279869079589844},
#  {'label': 'POSITIVE', 'score': 0.6390657424926758},
#  {'label': 'NEGATIVE', 'score': 0.7372838854789734},
#  {'label': 'POSITIVE', 'score': 0.6433911919593811},
#  {'label': 'NEGATIVE', 'score': 0.8106828331947327},
#  {'label': 'POSITIVE', 'score': 0.9956940412521362},
#  {'label': 'NEGATIVE', 'score': 0.6126403212547302},
#  {'label': 'NEGATIVE', 'score': 0.8093350529670715},
#  {'label': 'NEUTRAL', 'score': 0.5471960306167603},
#  {'label': 'NEGATIVE', 'score': 0.8366588950157166},
#  {'label': 'NEGATIVE', 'score': 0.631549596786499},
#  {'label': 'POSITIVE', 'score': 0.6906233429908752},
#  {'label': 'NEGATIVE', 'score': 0.5923716425895691},
#  {'label': 'NEUTRAL', 'score': 0.6457707285881042},
#  {'label': 'NEUTRAL', 'score': 0.5688093900680542},
#  {'label': 'POSITIVE', 'score': 0.9899405837059021},
#  {'label': 'POSITIVE', 'score': 0.8037646412849426},
#  {'label': 'NEGATIVE', 'score': 0.7357622385025024},
#  {'label': 'NEUTRAL', 'score': 0.5980633497238159},
#  {'label': 'NEGATIVE', 'score': 0.7225908637046814},
#  {'label': 'NEGATIVE', 'score': 0.8465204834938049},
#  {'label': 'NEUTRAL', 'score': 0.42722925543785095},
#  {'label': 'POSITIVE', 'score': 0.9940029978752136},
#  {'label': 'POSITIVE', 'score': 0.9921871423721313},
#  {'label': 'NEGATIVE', 'score': 0.5450912714004517},
#  {'label': 'POSITIVE', 'score': 0.9874482750892639},
#  {'label': 'POSITIVE', 'score': 0.9920809864997864},
#  {'label': 'NEGATIVE', 'score': 0.8272460699081421},
#  {'label': 'NEGATIVE', 'score': 0.8577848076820374},
#  {'label': 'NEGATIVE', 'score': 0.7662399411201477},
#  {'label': 'POSITIVE', 'score': 0.9907171130180359},
#  {'label': 'POSITIVE', 'score': 0.6227614283561707},
#  {'label': 'NEGATIVE', 'score': 0.6974867582321167},
#  {'label': 'NEUTRAL', 'score': 0.5060977935791016},
#  {'label': 'NEGATIVE', 'score': 0.6274840831756592},
#  {'label': 'POSITIVE', 'score': 0.9944813251495361},
#  {'label': 'NEGATIVE', 'score': 0.6250331401824951},
#  {'label': 'POSITIVE', 'score': 0.4966703951358795},
#  {'label': 'POSITIVE', 'score': 0.9932805895805359},
#  {'label': 'NEGATIVE', 'score': 0.4860115647315979},
#  {'label': 'NEGATIVE', 'score': 0.7254825234413147},
#  {'label': 'NEGATIVE', 'score': 0.589162290096283},
#  {'label': 'NEGATIVE', 'score': 0.8261699080467224},
#  {'label': 'NEGATIVE', 'score': 0.5776810646057129},
#  {'label': 'POSITIVE', 'score': 0.8617154955863953},
#  {'label': 'NEGATIVE', 'score': 0.4734850525856018},
#  {'label': 'POSITIVE', 'score': 0.9942512512207031},
#  {'label': 'POSITIVE', 'score': 0.8008862733840942},
#  {'label': 'POSITIVE', 'score': 0.6246145367622375},
#  {'label': 'POSITIVE', 'score': 0.6655680537223816},
#  {'label': 'NEUTRAL', 'score': 0.4843786954879761},
#  {'label': 'NEUTRAL', 'score': 0.45582258701324463},
#  {'label': 'NEGATIVE', 'score': 0.46733537316322327},
#  {'label': 'POSITIVE', 'score': 0.9912433624267578},
#  {'label': 'POSITIVE', 'score': 0.9924989342689514},
#  {'label': 'NEUTRAL', 'score': 0.7313252687454224},
#  {'label': 'NEGATIVE', 'score': 0.5928462147712708},
#  {'label': 'NEUTRAL', 'score': 0.5760046243667603},
#  {'label': 'POSITIVE', 'score': 0.9632190465927124},
#  {'label': 'NEGATIVE', 'score': 0.6183366775512695},
#  {'label': 'NEGATIVE', 'score': 0.7491546869277954},
#  {'label': 'NEUTRAL', 'score': 0.4642448425292969},
#  {'label': 'NEGATIVE', 'score': 0.5027589201927185},
#  {'label': 'NEGATIVE', 'score': 0.5966461300849915},
#  {'label': 'NEGATIVE', 'score': 0.666532039642334},
#  {'label': 'NEGATIVE', 'score': 0.751656174659729},
#  {'label': 'NEGATIVE', 'score': 0.7137651443481445},
#  {'label': 'POSITIVE', 'score': 0.8645423650741577},
#  {'label': 'NEUTRAL', 'score': 0.5599585771560669},
#  {'label': 'NEGATIVE', 'score': 0.7374386787414551},
#  {'label': 'NEGATIVE', 'score': 0.6141762137413025},
#  {'label': 'NEGATIVE', 'score': 0.5839129090309143},
#  {'label': 'NEUTRAL', 'score': 0.49374261498451233},
#  {'label': 'NEUTRAL', 'score': 0.47129157185554504},
#  {'label': 'POSITIVE', 'score': 0.9903646111488342},
#  {'label': 'POSITIVE', 'score': 0.9864306449890137},
#  {'label': 'POSITIVE', 'score': 0.7872347235679626},
#  {'label': 'NEGATIVE', 'score': 0.666293203830719},
#  {'label': 'POSITIVE', 'score': 0.9431511759757996},
#  {'label': 'NEUTRAL', 'score': 0.4360249936580658},
#  {'label': 'NEGATIVE', 'score': 0.7736487984657288},
#  {'label': 'NEUTRAL', 'score': 0.5781179070472717},
#  {'label': 'NEUTRAL', 'score': 0.5080989003181458},
#  {'label': 'NEGATIVE', 'score': 0.847463071346283},
#  {'label': 'POSITIVE', 'score': 0.38830286264419556},
#  {'label': 'NEGATIVE', 'score': 0.714266836643219},
#  {'label': 'POSITIVE', 'score': 0.7774817943572998},
#  {'label': 'POSITIVE', 'score': 0.6393230557441711},
#  {'label': 'POSITIVE', 'score': 0.9803035855293274},
#  {'label': 'POSITIVE', 'score': 0.8823459148406982},
#  {'label': 'NEGATIVE', 'score': 0.9106220006942749},
#  {'label': 'POSITIVE', 'score': 0.9938510656356812},
#  {'label': 'NEGATIVE', 'score': 0.4782075583934784},
#  {'label': 'POSITIVE', 'score': 0.9939141869544983},
#  {'label': 'NEGATIVE', 'score': 0.6470105051994324},
#  {'label': 'NEUTRAL', 'score': 0.6182873249053955},
#  {'label': 'NEGATIVE', 'score': 0.642435610294342},
#  {'label': 'NEGATIVE', 'score': 0.7913758754730225},
#  {'label': 'POSITIVE', 'score': 0.9877460598945618},
#  {'label': 'NEGATIVE', 'score': 0.8106105327606201},
#  {'label': 'POSITIVE', 'score': 0.7600234150886536},
#  {'label': 'NEUTRAL', 'score': 0.46919742226600647},
#  {'label': 'NEUTRAL', 'score': 0.623313307762146},
#  {'label': 'NEGATIVE', 'score': 0.5943771004676819},
#  {'label': 'POSITIVE', 'score': 0.9937950372695923},
#  ...]
